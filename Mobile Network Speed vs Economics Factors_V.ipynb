# %% [markdown]
# # Analysis of Mobile operators download speed and economic indicators in Europe.
# **Purpose**: Main focus of the study is to search the relevant data, collect mobile network speed and economic indicators data.
# Once data is collected, read the data in jupyter notebook and then select and choose the relevant columns and store them into a file. Once all relevant columns are stored in the table. Next step would be to draw some visualisation to better understand the which countries are performing better using matplot and seaborn.Once this process is done. We move on to conclusion.

# %%
#All the import statements:
import pandas as pd

#Read the Economic_indicator using pandas.

df = pd.read_excel(r'Economic_indicator.xlsx')
df
# Out:
#     Sr.No          Country Area in km² Population in km²  Urban Area in km²  \
# 0       1          Austria       83879             105.8                NaN
# 1       2          Albania       28750             99.28             1689.0
# 2       3       Azerbaijan       86600             115.7                NaN
# 3       4          Belgium       30530            376.02            12349.0
# 4       5         Bulgaria      111000             62.84             6679.0
# 5       6          Croatia       56590             71.88             5303.0
# 6       7           Cyprus        9250             129.6             2280.0
# 7       8   Czech Republic       78870             135.3                NaN
# 8       9          Denmark       42920             135.6             9295.0
# 9      10          Estonia       45,34             29.26             2615.0
# 10     11          Finland      338450             16.31            20052.0
# 11     12           France      549087             122.1            86463.0
# 12     13          Germany      357580             232.5            62374.0
# 13     14           Greece      131960             81.21            18519.0
# 14     15          Hungary       93030               105                NaN
# 15     16          Iceland      103000              3,51             1024.0
# 16     17          Ireland       70280             70.31             5638.0
# 17     18            Italy      301340             200.1            73541.0
# 18     19           Latvia       64490             29.66             3279.0
# 19     20        Lithuania       65286             42.69             4611.0
# 20     21       Luxembourg        2590             239.3              801.0
# 21     22            Malta         320              1571              293.0
# 22     23           Norway      385203             13.88            20282.0
# 23     24      Netherlands       41540             417.3            12803.0
# 24     25           Poland      312680             121.4            30501.0
# 25     26         Portugal       92226             111.4            12765.0
# 26     27          Romania      238400              81.9            15595.0
# 27     28  Slovak Republic       49030            111.02                NaN
# 28     29         Slovenia       20675               101             2509.0
# 29     30            Spain      505935             93.05            69795.0
# 30     31           Serbia       88360              78.6                NaN
# 31     32      Switzerland       41290             207.7             7898.0
# 32     33           Sweden      447430             22.99            31152.0
# 33     34          Ukraine      603550             73.54            32160.0
#
#     Agricultural areas km²  Forest Areas km²  Population  GDP in bn $ (2019)  \
# 0                    27183             38687     8877000        4.463147e+05
# 1                    11744              7716     2854000        1.527808e+07
# 2                    47701             11392    10023000        4.804765e+07
# 3                    13281              6834    11484000        5.296067e+05
# 4                    50122             38235     6976000        6.792718e+04
# 5                    15378             19222     4068000        6.041555e+04
# 6                     1272              1727     1199000        2.456465e+04
# 7                    42131             26672    10670000        2.464892e+05
# 8                    26109              6122     5819000        3.480780e+05
# 9                    10189             22887     1327000        3.138695e+04
# 10                   22732            222189     5520000        2.687612e+05
# 11                  287248            169907    67060000        2.715518e+06
# 12                  167553            114346    83133000        3.845630e+06
# 13                   77830             40539    10716000        2.098528e+05
# 14                   53467             20686     9770000        1.609672e+05
# 15                   18717               491      361313        2.418804e+07
# 16                   44303              7543     4941000        3.886987e+05
# 17                  129451             92978    60297000        2.001244e+06
# 18                   18847             33559     1913000        3.411720e+04
# 19                   30056             21799     2787000        5.421932e+04
# 20                    1232               813      619896        7.110492e+04
# 21                     102                 3      502653        1.478616e+04
# 22                    9858            121075     5348000        4.033364e+08
# 23                   18371              3760    17333000        9.090704e+05
# 24                  143695             94337    37971000        5.921644e+05
# 25                   37000             31824    10269000        2.376861e+05
# 26                  138347             68610    19357000        2.500774e+05
# 27                   19218             19400     5454000        1.054223e+05
# 28                    6167             12482     2088000        5.374216e+04
# 29                  262321            183939    47077000        1.394116e+06
# 30                   34687             27200     6945000        5.140917e+07
# 31                   15087             12538     8575000        7.030824e+08
# 32                   30385            280718    10285000        5.308329e+05
# 33                  412744             96568    44385000        1.537811e+08
#
#     GDP Per Capita ($) (2019) Mobile Subcription (2019)  \
# 0                     50277.3                  10726000
# 1                      5352.9                   1'789.2
# 2                      4793.6                       NaN
# 3                     46116.7                  11509573
# 4                      9737.6                   8134581
# 5                     14853.2                   4404652
# 6                     27858.4                   1243151
# 7                     23101.8                  13205000
# 8                     59822.1                   7243465
# 9                     23659.9                   1951051
# 10                    48685.9                   7150000
# 11                    40493.9                  72043000
# 12                    46258.9                 107200000
# 13                    19582.5                  11882081
# 14                    16475.7                  10272694
# 15                    66944.8                       NaN
# 16                    78661.0                   5145256
# 17                    33189.6                  80580548
# 18                    17836.4                   2071814
# 19                    19455.5                   4658823
# 20                   114704.6                    835900
# 21                    29416.2                    634768
# 22                    75419.6                       NaN
# 23                    52447.8                  21762000
# 24                    15595.2                  52268128
# 25                    23145.0                  11909751
# 26                    12919.5                  22671000
# 27                    19329.1                   7399534
# 28                    25739.2                   2511979
# 29                    29613.7                  55267594
# 30                     7402.4                       NaN
# 31                    81993.7                       NaN
# 32                    51610.1                  12678374
# 33                     3659.0                       NaN
#
#     Mobile Subcription/100 people (2019)
# 0                            119775297.0
# 1                            912930154.0
# 2                            106992453.0
# 3                            997421427.0
# 4                            116206325.0
# 5                             10664232.0
# 6                            143849919.0
# 7                            123535801.0
# 8                            125495853.0
# 9                            147177154.0
# 10                           129244367.0
# 11                           110614618.0
# 12                           128357032.0
# 13                           113449487.0
# 14                             1060716.0
# 15                            12194932.0
# 16                           105381695.0
# 17                           133080839.0
# 18                           108657223.0
# 19                            16882075.0
# 20                           135757777.0
# 21                           144143588.0
# 22                                   NaN
# 23                           127284521.0
# 24                           137955152.0
# 25                           116463262.0
# 26                           117074715.0
# 27                           135596782.0
# 28                           120846423.0
# 29                           118252902.0
# 30                           963709591.0
# 31                           127189335.0
# 32                           126324185.0
# 33                           130629436.0

# %% [markdown]
# #### Renamed Columns Accordingly

# %%
df.columns = ['Sr.No', 'Country', 'Area_in_sqkm', 'Population_in_sqkm',
       'Urban_Area_in_sqkm', 'Agricultural_areas_sqkm', 'Forest_Areas_sqkm',
       'Population', 'GDP_in_bn_2019', 'GDP_Per_Capita_2019',
       'Mobile_Subcription_2019', 'Mobile_Subcription_per_100_people_2019']

# %%
df.head()
# Out:
#    Sr.No     Country Area_in_sqkm Population_in_sqkm  Urban_Area_in_sqkm  \
# 0      1     Austria        83879              105.8                 NaN
# 1      2     Albania        28750              99.28              1689.0
# 2      3  Azerbaijan        86600              115.7                 NaN
# 3      4     Belgium        30530             376.02             12349.0
# 4      5    Bulgaria       111000              62.84              6679.0
#
#    Agricultural_areas_sqkm  Forest_Areas_sqkm  Population  GDP_in_bn_2019  \
# 0                    27183              38687     8877000       446314.74
# 1                    11744               7716     2854000     15278077.45
# 2                    47701              11392    10023000     48047647.06
# 3                    13281               6834    11484000       529606.71
# 4                    50122              38235     6976000        67927.18
#
#    GDP_Per_Capita_2019 Mobile_Subcription_2019  \
# 0              50277.3                10726000
# 1               5352.9                 1'789.2
# 2               4793.6                     NaN
# 3              46116.7                11509573
# 4               9737.6                 8134581
#
#    Mobile_Subcription_per_100_people_2019
# 0                             119775297.0
# 1                             912930154.0
# 2                             106992453.0
# 3                             997421427.0
# 4                             116206325.0

# %%
#Opened Opensignal_data.xlsx using pandas.
df1 = pd.read_excel('Opensignal_data.xlsx')
df1
# Out:
#    Europe Opensignal        Year Network type  \
# 0            Albania  Q1-Q2 2019       Mobile
# 1            Austria  Q1-Q2 2019       Mobile
# 2         Azerbaijan  Q1-Q2 2019       Mobile
# 3            Belarus  Q1-Q2 2019       Mobile
# 4            Belgium  Q1-Q2 2019       Mobile
# 5           Bulgaria  Q1-Q2 2019       Mobile
# 6            Croatia  Q1-Q2 2019       Mobile
# 7     Czech Republic  Q1-Q2 2019       Mobile
# 8            Denmark  Q1-Q2 2019       Mobile
# 9            Finland  Q1-Q2 2019       Mobile
# 10            France  Q1-Q2 2019       Mobile
# 11           Germany  Q1-Q2 2019       Mobile
# 12            Greece  Q1-Q2 2019       Mobile
# 13           Hungary  Q1-Q2 2019       Mobile
# 14           Ireland  Q1-Q2 2019       Mobile
# 15             Italy  Q1-Q2 2019       Mobile
# 16       Netherlands  Q1-Q2 2019       Mobile
# 17            Norway  Q1-Q2 2019       Mobile
# 18            Poland  Q1-Q2 2019       Mobile
# 19          Portugal  Q1-Q2 2019       Mobile
# 20           Romania  Q1-Q2 2019       Mobile
# 21            Serbia  Q1-Q2 2019       Mobile
# 22          Slovakia  Q1-Q2 2019       Mobile
# 23             Spain  Q1-Q2 2019       Mobile
# 24            Sweden  Q1-Q2 2019       Mobile
# 25       Switzerland  Q1-Q2 2019       Mobile
# 26           Ukraine  Q1-Q2 2019       Mobile
# 27    United Kingdom  Q1-Q2 2019       Mobile
#
#     Download Speed Experience (Mbps)  Upload Speed Experience (Mbps)  \
# 0                               21.4                             6.2
# 1                               27.5                             8.8
# 2                               13.4                             3.4
# 3                                7.7                             4.3
# 4                               34.2                            11.9
# 5                               22.5                             8.2
# 6                               26.7                            10.0
# 7                               31.5                            12.5
# 8                               34.6                            15.3
# 9                               27.0                            10.0
# 10                              25.2                             6.1
# 11                              22.6                             7.6
# 12                              23.8                             6.9
# 13                              32.7                            11.4
# 14                              16.2                             5.8
# 15                              19.9                             7.3
# 16                              42.4                            12.2
# 17                              48.2                            14.5
# 18                              17.3                             6.3
# 19                              21.6                             8.0
# 20                              20.6                             7.8
# 21                              21.5                             7.4
# 22                              23.3                             8.5
# 23                              24.8                             9.2
# 24                              30.8                             9.7
# 25                              35.2                            11.2
# 26                              11.2                             5.1
# 27                              21.7                             7.4
#
#     Latency Experience (ms)  4G Availability (%)  \
# 0                      74.1                 72.2
# 1                      38.6                 86.6
# 2                      61.9                 72.9
# 3                      56.5                 68.6
# 4                      35.3                 90.4
# 5                      40.7                 79.5
# 6                      50.4                 83.4
# 7                      33.7                 90.6
# 8                      34.8                 88.6
# 9                      41.6                 89.5
# 10                     51.6                 79.7
# 11                     44.4                 76.9
# 12                     42.0                 83.2
# 13                     33.4                 91.4
# 14                     48.9                 63.7
# 15                     55.1                 79.0
# 16                     38.8                 92.8
# 17                     42.3                 95.5
# 18                     47.1                 82.9
# 19                     42.2                 82.6
# 20                     41.3                 78.8
# 21                     37.1                 83.8
# 22                     40.7                 84.5
# 23                     46.6                 87.4
# 24                     41.4                 91.1
# 25                     34.0                 89.6
# 26                     60.6                 66.4
# 27                     46.0                 84.7
#
#     Video Experience (out of 100)
# 0                            57.6
# 1                            73.3
# 2                            53.5
# 3                            51.2
# 4                            70.5
# 5                            66.6
# 6                            69.5
# 7                            73.3
# 8                            72.5
# 9                            69.4
# 10                           62.5
# 11                           66.3
# 12                           65.2
# 13                           74.2
# 14                           61.7
# 15                           64.1
# 16                           72.2
# 17                           74.7
# 18                           63.0
# 19                           66.7
# 20                           62.3
# 21                           65.7
# 22                           69.4
# 23                           68.2
# 24                           70.8
# 25                           70.0
# 26                           54.5
# 27                           66.2

# %%
#Renmaed the column names
df1.columns
# Out:
# Index(['Europe Opensignal', 'Year', 'Network type',
#        'Download Speed Experience (Mbps)', 'Upload Speed Experience (Mbps)',
#        'Latency Experience (ms)', '4G Availability (%)',
#        'Video Experience (out of 100)'],
#       dtype='object')

# %%
df1.columns = ['Europe_Opensignal', 'Year', 'Network_type',
       'Download_Speed_Experience_Mbps', 'Upload_Speed_Experience_Mbps',
       'Latency_Experience_ms', '4G_Availability_%',
       'Video_Experience_out_of_100']

# %%
#Checked first 10 rows
df1.head(10)
# Out:
#   Europe_Opensignal        Year Network_type  Download_Speed_Experience_Mbps  \
# 0           Albania  Q1-Q2 2019       Mobile                            21.4
# 1           Austria  Q1-Q2 2019       Mobile                            27.5
# 2        Azerbaijan  Q1-Q2 2019       Mobile                            13.4
# 3           Belarus  Q1-Q2 2019       Mobile                             7.7
# 4           Belgium  Q1-Q2 2019       Mobile                            34.2
# 5          Bulgaria  Q1-Q2 2019       Mobile                            22.5
# 6           Croatia  Q1-Q2 2019       Mobile                            26.7
# 7    Czech Republic  Q1-Q2 2019       Mobile                            31.5
# 8           Denmark  Q1-Q2 2019       Mobile                            34.6
# 9           Finland  Q1-Q2 2019       Mobile                            27.0
#
#    Upload_Speed_Experience_Mbps  Latency_Experience_ms  4G_Availability_%  \
# 0                           6.2                   74.1               72.2
# 1                           8.8                   38.6               86.6
# 2                           3.4                   61.9               72.9
# 3                           4.3                   56.5               68.6
# 4                          11.9                   35.3               90.4
# 5                           8.2                   40.7               79.5
# 6                          10.0                   50.4               83.4
# 7                          12.5                   33.7               90.6
# 8                          15.3                   34.8               88.6
# 9                          10.0                   41.6               89.5
#
#    Video_Experience_out_of_100
# 0                         57.6
# 1                         73.3
# 2                         53.5
# 3                         51.2
# 4                         70.5
# 5                         66.6
# 6                         69.5
# 7                         73.3
# 8                         72.5
# 9                         69.4

# %%
df.head()
# Out:
#    Sr.No     Country Area in km² Population in km²  Urban Area in km²  \
# 0      1     Austria       83879             105.8                NaN
# 1      2     Albania       28750             99.28             1689.0
# 2      3  Azerbaijan       86600             115.7                NaN
# 3      4     Belgium       30530            376.02            12349.0
# 4      5    Bulgaria      111000             62.84             6679.0
#
#    Agricultural areas km²  Forest Areas km²  Population  GDP in bn $ (2019)  \
# 0                   27183             38687     8877000           446314.74
# 1                   11744              7716     2854000         15278077.45
# 2                   47701             11392    10023000         48047647.06
# 3                   13281              6834    11484000           529606.71
# 4                   50122             38235     6976000            67927.18
#
#    GDP Per Capita ($) (2019) Mobile Subcription (2019)  \
# 0                    50277.3                  10726000
# 1                     5352.9                   1'789.2
# 2                     4793.6                       NaN
# 3                    46116.7                  11509573
# 4                     9737.6                   8134581
#
#    Mobile Subcription/100 people (2019)
# 0                           119775297.0
# 1                           912930154.0
# 2                           106992453.0
# 3                           997421427.0
# 4                           116206325.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Sr.No                                 34 non-null     int64
#  1   Country                               34 non-null     object
#  2   Area in km²                           34 non-null     object
#  3   Population in km²                     34 non-null     object
#  4   Urban Area in km²                     28 non-null     float64
#  5   Agricultural areas km²                34 non-null     int64
#  6   Forest Areas km²                      34 non-null     int64
#  7   Population                            34 non-null     int64
#  8   GDP in bn $ (2019)                    34 non-null     float64
#  9   GDP Per Capita ($) (2019)             34 non-null     float64
#  10  Mobile Subcription (2019)             28 non-null     object
#  11  Mobile Subcription/100 people (2019)  33 non-null     float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 3.3+ KB

# %%
df.describe() #Summary of Economic Indicators
# Out:
#            Sr.No  Urban Area in km²  Agricultural areas km²  Forest Areas km²  \
# count  34.000000          28.000000               34.000000         34.000000
# mean   17.500000       19723.750000            65427.294118      54611.705882
# std     9.958246       24248.329648            93252.164385      69589.105914
# min     1.000000         293.000000              102.000000          3.000000
# 25%     9.250000        3113.000000            15159.750000       8635.000000
# 50%    17.500000       10822.000000            28619.500000      24779.500000
# 75%    25.750000       22836.750000            52630.750000      86886.000000
# max    34.000000       86463.000000           412744.000000     280718.000000
#
#          Population  GDP in bn $ (2019)  GDP Per Capita ($) (2019)  \
# count  3.400000e+01        3.400000e+01                  34.000000
# mean   1.547073e+07        4.160928e+07               35180.964706
# std    2.090227e+07        1.379052e+08               26074.093489
# min    3.613130e+05        1.478616e+04                3659.000000
# 25%    3.157500e+06        7.968426e+04               16815.875000
# 50%    7.775500e+06        3.683884e+05               26798.800000
# 75%    1.129200e+07        2.536950e+06               49879.450000
# max    8.313300e+07        7.030824e+08              114704.600000
#
#        Mobile Subcription/100 people (2019)
# count                          3.300000e+01
# mean                           1.867939e+08
# std                            2.509728e+08
# min                            1.060716e+06
# 25%                            1.134495e+08
# 50%                            1.254959e+08
# 75%                            1.355968e+08
# max                            9.974214e+08

# %%
#Took transpose to check the structure of dataframe.
df.describe().transpose()
# Out:
#                                       count          mean           std  \
# Sr.No                                  34.0  1.750000e+01  9.958246e+00
# Urban Area in km²                      28.0  1.972375e+04  2.424833e+04
# Agricultural areas km²                 34.0  6.542729e+04  9.325216e+04
# Forest Areas km²                       34.0  5.461171e+04  6.958911e+04
# Population                             34.0  1.547073e+07  2.090227e+07
# GDP in bn $ (2019)                     34.0  4.160928e+07  1.379052e+08
# GDP Per Capita ($) (2019)              34.0  3.518096e+04  2.607409e+04
# Mobile Subcription/100 people (2019)   33.0  1.867939e+08  2.509728e+08
#
#                                              min           25%           50%  \
# Sr.No                                       1.00  9.250000e+00  1.750000e+01
# Urban Area in km²                         293.00  3.113000e+03  1.082200e+04
# Agricultural areas km²                    102.00  1.515975e+04  2.861950e+04
# Forest Areas km²                            3.00  8.635000e+03  2.477950e+04
# Population                             361313.00  3.157500e+06  7.775500e+06
# GDP in bn $ (2019)                      14786.16  7.968426e+04  3.683884e+05
# GDP Per Capita ($) (2019)                3659.00  1.681588e+04  2.679880e+04
# Mobile Subcription/100 people (2019)  1060716.00  1.134495e+08  1.254959e+08
#
#                                                75%           max
# Sr.No                                 2.575000e+01  3.400000e+01
# Urban Area in km²                     2.283675e+04  8.646300e+04
# Agricultural areas km²                5.263075e+04  4.127440e+05
# Forest Areas km²                      8.688600e+04  2.807180e+05
# Population                            1.129200e+07  8.313300e+07
# GDP in bn $ (2019)                    2.536950e+06  7.030824e+08
# GDP Per Capita ($) (2019)             4.987945e+04  1.147046e+05
# Mobile Subcription/100 people (2019)  1.355968e+08  9.974214e+08

# %%
df['Country'].head()
# Out:
# 0       Austria
# 1       Albania
# 2    Azerbaijan
# 3       Belgium
# 4      Bulgaria
# Name: Country, dtype: object

# %%
['Country', 'Urban_Area_in_sqkm']
# Out:
# ['Country', 'Urban_Area_in_sqkm']

# %%
df[['Country', 'Urban_Area_in_sqkm']].head()
# Out:
#       Country  Urban_Area_in_sqkm
# 0     Austria                 NaN
# 1     Albania              1689.0
# 2  Azerbaijan                 NaN
# 3     Belgium             12349.0
# 4    Bulgaria              6679.0

# %%
df.Urban_Area_in_sqkm.head()
# Out:
# 0        NaN
# 1     1689.0
# 2        NaN
# 3    12349.0
# 4     6679.0
# Name: Urban_Area_in_sqkm, dtype: float64

# %%
df[['Country', 'Urban_Area_in_sqkm']]
# Out:
#             Country  Urban_Area_in_sqkm
# 0           Austria                 NaN
# 1           Albania              1689.0
# 2        Azerbaijan                 NaN
# 3           Belgium             12349.0
# 4          Bulgaria              6679.0
# 5           Croatia              5303.0
# 6            Cyprus              2280.0
# 7    Czech Republic                 NaN
# 8           Denmark              9295.0
# 9           Estonia              2615.0
# 10          Finland             20052.0
# 11           France             86463.0
# 12          Germany             62374.0
# 13           Greece             18519.0
# 14          Hungary                 NaN
# 15          Iceland              1024.0
# 16          Ireland              5638.0
# 17            Italy             73541.0
# 18           Latvia              3279.0
# 19        Lithuania              4611.0
# 20       Luxembourg               801.0
# 21            Malta               293.0
# 22           Norway             20282.0
# 23      Netherlands             12803.0
# 24           Poland             30501.0
# 25         Portugal             12765.0
# 26          Romania             15595.0
# 27  Slovak Republic                 NaN
# 28         Slovenia              2509.0
# 29            Spain             69795.0
# 30           Serbia                 NaN
# 31      Switzerland              7898.0
# 32           Sweden             31152.0
# 33          Ukraine             32160.0

# %%
''''Imported matplot and 
seaborn for visualisatoin of the Economic Indicators.'''
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings


warnings.filterwarnings('ignore')

# %%
#Visualised density vs population.
vis1 = sns.distplot(df['Population'], bins = 5)

# %%
#Visualised Mobile subscriptions per 100 people vs GDP per capita. 
vis2 = sns.boxplot(data=df, x='GDP_Per_Capita_2019', y='Mobile_Subcription_per_100_people_2019')

# %%
#Visualised Mobile GDP per capita. 
vis4 = sns.distplot(df['GDP_Per_Capita_2019'], bins=10)

# %%
#Plotted Mobile subscriptions per 100 people vs GDP per capita with hue as country.
vis5 = sns.lmplot(data=df, x='GDP_Per_Capita_2019', y='Mobile_Subcription_per_100_people_2019', \
                  fit_reg=False,hue='Country')

# %%
#Plotted Area_in_sqkm and Mobile_Subcription_per_100_people_2019 using seaborn.
sns.set_theme(style="ticks", palette="pastel")

sns.boxplot(x="Area_in_sqkm", y="Mobile_Subcription_per_100_people_2019",
        palette=["m", "g"],
            data=df)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### Visualisation for Mobile Network Data

# %%
#Filtered out countries with download speed experience greater than 30.
downloadspeed = df1.loc[ df1['Download_Speed_Experience_Mbps'] >30 ]
downloadspeed
# Out:
#    Europe_Opensignal        Year Network_type  Download_Speed_Experience_Mbps  \
# 4            Belgium  Q1-Q2 2019       Mobile                            34.2
# 7     Czech Republic  Q1-Q2 2019       Mobile                            31.5
# 8            Denmark  Q1-Q2 2019       Mobile                            34.6
# 13           Hungary  Q1-Q2 2019       Mobile                            32.7
# 16       Netherlands  Q1-Q2 2019       Mobile                            42.4
# 17            Norway  Q1-Q2 2019       Mobile                            48.2
# 24            Sweden  Q1-Q2 2019       Mobile                            30.8
# 25       Switzerland  Q1-Q2 2019       Mobile                            35.2
#
#     Upload_Speed_Experience_Mbps  Latency_Experience_ms  4G_Availability_%  \
# 4                           11.9                   35.3               90.4
# 7                           12.5                   33.7               90.6
# 8                           15.3                   34.8               88.6
# 13                          11.4                   33.4               91.4
# 16                          12.2                   38.8               92.8
# 17                          14.5                   42.3               95.5
# 24                           9.7                   41.4               91.1
# 25                          11.2                   34.0               89.6
#
#     Video_Experience_out_of_100
# 4                          70.5
# 7                          73.3
# 8                          72.5
# 13                         74.2
# 16                         72.2
# 17                         74.7
# 24                         70.8
# 25                         70.0

# %%
#Plotted countries and download speed experience.
vis21 = sns.boxplot(data=downloadspeed, x='Europe_Opensignal', y='Download_Speed_Experience_Mbps') 
vis21.set(xlim=(0,5))
# Out:
# [(0.0, 5.0)]

# %%
#Filtered out the dataframes on the basis of upload speed experience greater than 10.
uploadspeed = df1.loc[ df1['Upload_Speed_Experience_Mbps'] >=10 ]
uploadspeed
vis22 = sns.boxplot(data=uploadspeed, x='Europe_Opensignal', y='Upload_Speed_Experience_Mbps') 
vis22.set(xlim=(0,5))
# Out:
# [(0.0, 5.0)]

# %%
#Filtered out the dataframes on the basis of upload speed experience greater than 10.
videoexperience = df1.loc[ df1['Video_Experience_out_of_100'] >=65 ]
videoexperience
vis22 = sns.boxplot(data=videoexperience, x='Europe_Opensignal', y='Video_Experience_out_of_100') 
vis22.set(xlim=(0,5))
# Out:
# [(0.0, 5.0)]

# %%
uploadspeed = df1.loc[ df1['Upload_Speed_Experience_Mbps'] >=10 ]
uploadspeed
# Out:
#    Europe_Opensignal        Year Network_type  Download_Speed_Experience_Mbps  \
# 4            Belgium  Q1-Q2 2019       Mobile                            34.2
# 6            Croatia  Q1-Q2 2019       Mobile                            26.7
# 7     Czech Republic  Q1-Q2 2019       Mobile                            31.5
# 8            Denmark  Q1-Q2 2019       Mobile                            34.6
# 9            Finland  Q1-Q2 2019       Mobile                            27.0
# 13           Hungary  Q1-Q2 2019       Mobile                            32.7
# 16       Netherlands  Q1-Q2 2019       Mobile                            42.4
# 17            Norway  Q1-Q2 2019       Mobile                            48.2
# 25       Switzerland  Q1-Q2 2019       Mobile                            35.2
#
#     Upload_Speed_Experience_Mbps  Latency_Experience_ms  4G_Availability_%  \
# 4                           11.9                   35.3               90.4
# 6                           10.0                   50.4               83.4
# 7                           12.5                   33.7               90.6
# 8                           15.3                   34.8               88.6
# 9                           10.0                   41.6               89.5
# 13                          11.4                   33.4               91.4
# 16                          12.2                   38.8               92.8
# 17                          14.5                   42.3               95.5
# 25                          11.2                   34.0               89.6
#
#     Video_Experience_out_of_100
# 4                          70.5
# 6                          69.5
# 7                          73.3
# 8                          72.5
# 9                          69.4
# 13                         74.2
# 16                         72.2
# 17                         74.7
# 25                         70.0

# %% [markdown]
# ### Conclusion

# %%
#In economic indicators, GDP does not seem to have direct impact based on visualisation and data available. More work needs 
#to be done to learn more about the relationship between GDP and mobile subscription. Similarly, there are more varibale needs
#be taken into consideration to develop a relationship between area in square kilometer and mobile subscription. 

#In mobile network data visualisation.Norway,Netherlands and Switzerland came out as winner in download speed experience. It is
#important to know that Netherlands has such dense area and population meaning mobile operators do not have to install many
#base stations to cover the population. Hence, low cost and much better network quality.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\35844'
